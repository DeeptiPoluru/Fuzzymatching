# %% [markdown]
# # Program to clean assignee data from Patent View
# Input files:
# rawassignee.tsv
#
# Output files:
# rawpv_clean_23apr20.csv

# %%
import pandas as pd
import numpy as np
from cleanco import cleanco
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process 
import  re
import urllib.request as urllib2
import json
import datetime

# %% [markdown]
# ### rawassignee.tsv

# %%
df = pd.read_csv("rawassignee.tsv", delimiter='\t')

# %%
len(df) # no of observations in assignee.tsv is 6,387,373
# Out:
# 6387373

# %%
df.head()
# Out:
#                         uuid patent_id               assignee_id  \
# 0  0000p94wkezw94s8cz7dbxlvz   5856666  org_fijoKOoRhIzrkYzecWF9
# 1  00013vk881wap9u4mbo7lwwhp   5204210  org_UrbE3xev7LUsnuvRjbep
# 2  000192sn2u10kzpikl4s7h3r0   5302149  org_JcXwBlJtb1uvcPKHeaYX
# 3  0001ycvv6sz1ju07ss99nhxi1   9104354  org_7fE5f5nnY6dbOc3vSaXb
# 4  0001z7ws4m14aqdb3tv99u550   6584517  org_sj7olrHxASyJDNVGczBe
#
#               rawlocation_id  type name_first name_last  \
# 0  orskbf54s58e97lkmw8na5rpx     2        NaN       NaN
# 1  mue862v5lcjdhzqqk86ei75kj     2        NaN       NaN
# 2  o1h9dqdv0yq7dt1b1vmrcal9h     3        NaN       NaN
# 3  rspbpqcajvm09r1ew9mgnpx37     3        NaN       NaN
# 4  l1gyelp5jcg0hakk9smmhsdgr     2        NaN       NaN
#
#                                         organization  sequence
# 0                           U.S. Philips Corporation         0
# 1                                  Xerox Corporation         0
# 2  Commonwealth Scientific & Industrial Research ...         1
# 3                             Canon Kabushiki Kaisha         0
# 4                        Cypress Semiconductor Corp.         0

# %%
df[['uuid','organization','patent_id','assignee_id']].nunique()
# Out:
# uuid            6387373
# organization     682984
# patent_id       6177084
# assignee_id      486381
# dtype: int64

# %%
df.columns
# Out:
# Index(['uuid', 'patent_id', 'assignee_id', 'rawlocation_id', 'type',
#        'name_first', 'name_last', 'organization', 'sequence'],
#       dtype='object')

# %%
# remove redundant columns
del df['name_last'], df['name_first'], df['uuid'], df['rawlocation_id']

# %%
# remove organization is nan
df = df[~df['organization'].isna()]

# %%
df.nunique()
# Out:
# patent_id       6126629
# assignee_id      438318
# type                 18
# organization     682984
# sequence             16
# dtype: int64

# %% [markdown]
# assignee type (1- Unassigned, 2 - US Company or Corporation, 3 - Foreign Company or Corporation, 4 - US Individual, 5 - Foreign Individual, 6 - US Federal Government, 7 - Foreign Government, 8 - US County Government, 9 - US State Government. Note: A "1" appearing before any of these codes signifies part interest)

# %% [markdown]
# Sequence: order in which assignee appears in patent file

# %%
len(df)
# Out:
# 6318286

# %%
df_corp = df[df['type'].isin([2,3])]

# %%
df_corp.nunique()
# Out:
# patent_id       6070872
# assignee_id      436099
# type                  2
# organization     678463
# sequence             16
# dtype: int64

# %%
df.nunique()
# Out:
# patent_id       6126629
# assignee_id      438318
# type                 18
# organization     682984
# sequence             16
# dtype: int64

# %%
df_corp.isna().sum()
# Out:
# patent_id       0
# assignee_id     0
# type            0
# organization    0
# sequence        0
# dtype: int64

# %%
# remove any duplicates
df2 = df_corp[['assignee_id','organization']]

# %%
df2.nunique() #assignee_id 436099; irganization = 678463
# Out:
# assignee_id     436099
# organization    678463
# dtype: int64

# %%
df2 = df2.drop_duplicates(keep = 'first')

# %%
len(df2)
# Out:
# 684849

# %%
df2['organization'] = df2['organization'].str.encode('ascii', 'ignore').str.decode('ascii')

# %%
df2.nunique() #677775
# Out:
# assignee_id     436099
# organization    677775
# dtype: int64

# %%
#################################################

# %%
# remove text from braces
df2['brace'] = df2['organization'].apply(lambda x: re.findall(r"\(.*\)",x))

# %%
df2['bracelen'] = df2['brace'].apply(lambda x: len(x))
df2['bracelen'].value_counts() # bracelen text in braces
# Out:
# 0    670356
# 1     14493
# Name: bracelen, dtype: int64

# %%
#extract text from brace as string
df2.loc[df2['bracelen']==1, 'bractext']  = df2[df2['bracelen']==1]['brace'].apply(lambda x: x[0][1:-1])

# %%
frq = df2[~df2['bractext'].isnull()]['bractext'].value_counts()

# %%
frq[(frq==5)]
# Out:
# ATO-DLO          5
# Huizhou          5
# San Diego        5
# Cird Galderma    5
# FPD              5
#                 ..
# ICREA            5
# A-P              5
# Belgium          5
# KGaA             5
# UEB              5
# Name: bractext, Length: 78, dtype: int64

# %%
# ANVAR, Kobe Steel, Ltd. ,Henkel KGaA ,USINOR,SEPM,KIGAM,RWTH,,APHP

# %%
df2['bractext'].fillna("", inplace=True)

# %%
# remove text from braces
df2['organization2'] = df2['organization'].str.replace(r"\(.*\)","")

# %%
df2[df2['organization2']==""]
# Out:
#                       assignee_id  \
# 841917   org_4LpvuqQrSxPINNkwHmIG
# 2592662  org_m1wjmqxUyvyUHgBZoadC
# 6132223  org_IWh3ZcciYsd6R9mI8Nkm
#
#                                               organization  \
# 841917                                  (Kobe Steel, Ltd.)
# 2592662           (Sasol Technology (Proprietary) Limited)
# 6132223  (INSERM) (Institut National de la Sante et de ...
#
#                                                      brace  bracelen  \
# 841917                                [(Kobe Steel, Ltd.)]         1
# 2592662         [(Sasol Technology (Proprietary) Limited)]         1
# 6132223  [(INSERM) (Institut National de la Sante et de...         1
#
#                                                   bractext organization2
# 841917                                    Kobe Steel, Ltd.
# 2592662             Sasol Technology (Proprietary) Limited
# 6132223  INSERM) (Institut National de la Sante et de l...

# %%
df2.loc[df2.organization2=="","organization2" ] = df2.loc[df2.organization2=="","bractext"]

# %%
df2[df2['organization2']==""]
# Out:
# Empty DataFrame
# Columns: [assignee_id, organization, brace, bracelen, bractext, organization2]
# Index: []

# %%
df2.columns
# Out:
# Index(['assignee_id', 'organization', 'brace', 'bracelen', 'bractext',
#        'organization2'],
#       dtype='object')

# %%
df2.bractext.value_counts()
# Out:
#                                   670356
# UK                                   485
# Proprietary                          386
# Singapore                            264
# Shanghai                             259
#                                    ...
# Jiashan                                1
# PIMS                                   1
# a French Societe Anonyme               1
# Idemitsu Kosan Co., Ltd.               1
# Design Screen Haute Definition         1
# Name: bractext, Length: 4316, dtype: int64

# %%
df2[(df2['bractext']=="UK")]['organization'] #Trailmor [Proprietary] Limited #Oxford Instruments (UK) Limited
# Out:
# 954                Oxford Instruments (UK) Limited
# 13272                    Premium Genetics (UK) LTD
# 26509                         Meggitt (UK) Limited
# 27081            Dialog Semiconductor (UK) Limited
# 27230                Oxford Biomedica (UK) Limited
#                             ...
# 6262472              Martin Manufacturing (UK) PLC
# 6266809              Wagon Automotive (UK) Limited
# 6270064    Bowe Systems and Machinery (UK) Limited
# 6290531                     Equipbaby (UK) Limited
# 6306129                     ITF Licensing (UK) LTD
# Name: organization, Length: 485, dtype: object

# %%
# remove text from braces
df2['organization3'] = df2['organization2'].str.replace(r"\(.*\)","")

# %%
df2.loc[df2['bractext'].str.contains("Kobe Steel"), "organization3"] = "Kobe Steel, Ltd."

# %%
df2[df2['bractext'].str.contains("Kobe")]
# Out:
#                       assignee_id  \
# 7031     org_B2jlMPhNiLEbDrkLzyUa
# 102358   org_4LpvuqQrSxPINNkwHmIG
# 799330   org_B2jlMPhNiLEbDrkLzyUa
# 841917   org_4LpvuqQrSxPINNkwHmIG
# 1748079  org_VnBMyp004Q1wOnzQ0ohl
# 3212511  org_uuvhltTWQnh0HjyWEX5u
# 4411669  org_B2jlMPhNiLEbDrkLzyUa
# 4767778  org_B2jlMPhNiLEbDrkLzyUa
# 5326159  org_VnBMyp004Q1wOnzQ0ohl
#
#                                               organization  \
# 7031     Kabushiki Kaisha Kobe Seiko Sho (Kobe Steel, L...
# 102358                 Kabushiki Kaisha (Kobe Steel, Ltd.)
# 799330   Kabushiki Kaisha Kobe Seiko Sho (Kobe Steel Ltd.)
# 841917                                  (Kobe Steel, Ltd.)
# 1748079  Kabushiki Kaisha Kobe Sieko Sho (Kobe Steel, L...
# 3212511  Kabuhsiki Kaisha Kobe Seiko Sho (Kobe Steel, L...
# 4411669  Kabushiki Kaisha Kobe Seiko Sho (Kobe Steel, Ltd)
# 4767778  Kabushiki Kaisha Kobe Seiko Sho (Kobe Steel Ltd).
# 5326159  Kabushiki Kaisha Kobe Seiko Sho (Kobe Steel, L...
#
#                         brace  bracelen          bractext  \
# 7031     [(Kobe Steel, Ltd.)]         1  Kobe Steel, Ltd.
# 102358   [(Kobe Steel, Ltd.)]         1  Kobe Steel, Ltd.
# 799330    [(Kobe Steel Ltd.)]         1   Kobe Steel Ltd.
# 841917   [(Kobe Steel, Ltd.)]         1  Kobe Steel, Ltd.
# 1748079  [(Kobe Steel, Ltd.)]         1  Kobe Steel, Ltd.
# 3212511  [(Kobe Steel, Ltd.)]         1  Kobe Steel, Ltd.
# 4411669   [(Kobe Steel, Ltd)]         1   Kobe Steel, Ltd
# 4767778    [(Kobe Steel Ltd)]         1    Kobe Steel Ltd
# 5326159  [(Kobe Steel, Ltd.)]         1  Kobe Steel, Ltd.
#
#                                   organization2     organization3
# 7031           Kabushiki Kaisha Kobe Seiko Sho   Kobe Steel, Ltd.
# 102358                        Kabushiki Kaisha   Kobe Steel, Ltd.
# 799330         Kabushiki Kaisha Kobe Seiko Sho   Kobe Steel, Ltd.
# 841917                         Kobe Steel, Ltd.  Kobe Steel, Ltd.
# 1748079        Kabushiki Kaisha Kobe Sieko Sho   Kobe Steel, Ltd.
# 3212511        Kabuhsiki Kaisha Kobe Seiko Sho   Kobe Steel, Ltd.
# 4411669        Kabushiki Kaisha Kobe Seiko Sho   Kobe Steel, Ltd.
# 4767778       Kabushiki Kaisha Kobe Seiko Sho .  Kobe Steel, Ltd.
# 5326159  Kabushiki Kaisha Kobe Seiko Sho  Steel  Kobe Steel, Ltd.

# %%
###check text from square braces

# %%
# remove text from braces
df2['brace1'] = df2['organization3'].apply(lambda x: re.findall(r"\[.*\]",x))

# %%
df2['bracelen1'] = df2['brace1'].apply(lambda x: len(x))
df2['bracelen1'].value_counts() # bracelen text in braces
# Out:
# 0    684824
# 1        25
# Name: bracelen1, dtype: int64

# %%
# extract text from brace as string
df2.loc[df2['bracelen1']==1, 'bractext1']  = df2[df2['bracelen1']==1]['brace1'].apply(lambda x: x[0][1:-1])

# %%
df2[~df2['bractext1'].isnull()]['organization3'].value_counts().index
# Out:
# Index(['[27]7.ai, Inc.', 'Rand Steel Technology [Proprietary] Limited',
#        'Reuter Chemische Apparatebau KG [DE/DE] ', 'Generics [UK] Limited',
#        'Generics [UK]Limited', 'Generics [UK]  Limited',
#        'Pacific Biomedical Research, Inc. [Cell Mart, Inc.]',
#        'P. Robertet & Cie [Societe Anomyme]',
#        'BASF Lacke + Farben Aktiengesellschaft[DE/DE]',
#        '[Bu:st]GmbH Beratungsunternehmen fr Systeme und Technologien',
#        'Syminex [Societe Anonyme]',
#        'Kinetic Energy Corporation [a wholly owned subsidiary of SolarWindow Technologies, Inc.]',
#        '[X+1] Solutions, Inc.', '[24] 7.ai, Inc.',
#        'DIRECTOR GENERAL, DEFENCE RESEARCH & DEVELOPMENT ORGANIZATION [DRDO]',
#        'BRY AIR [ASIA] PVT. LTD.', '[24]7 .AI, INC.', '[24]7.AI, INC.',
#        'True[X] Media Inc.', 'Textil Copper Andino S.A. [CL/CL]',
#        '[24] 7 .ai, Inc.', 'Reuter Chemische Apparatebau KG [DE/DE]',
#        '[24]7.ai, Inc.', '[24]7.AI, Inc.', 'Trailmor [Proprietary] Limited'],
#       dtype='object')

# %%
df2['bractext1'].value_counts().index
# Out:
# Index(['24', 'DE/DE', 'UK', 'Proprietary',
#        'a wholly owned subsidiary of SolarWindow Technologies, Inc.', 'Bu:st',
#        'Societe Anonyme', 'X+1', 'X', 'Cell Mart, Inc.', 'Societe Anomyme',
#        'ASIA', '27', 'CL/CL', 'DRDO'],
#       dtype='object')

# %%
lst = ['UK', 'DE/DE', 'ASIA',  'Proprietary',
       'a wholly owned subsidiary of SolarWindow Technologies, Inc.',
       'Societe Anomyme', 'Bu:st', 'DRDO', 'Cell Mart, Inc.', 'CL/CL',
       'Societe Anonyme']

df2.loc[df2['bractext1'].isin(lst),"organization3"] = df2.loc[df2['bractext1'].isin(lst),"organization3"].str.replace(r"\[.*\]","")

# %%
df2[df2['bracelen1']==1][['organization','organization3']]
# Out:
#                                               organization  \
# 101286                      Trailmor [Proprietary] Limited
# 114949                               Generics [UK] Limited
# 273573   [Bu:st]GmbH Beratungsunternehmen fr Systeme un...
# 297148                               [X+1] Solutions, Inc.
# 405573                                      [24]7.ai, Inc.
# 477425                                Generics [UK]Limited
# 583327                                      [24]7.AI, Inc.
# 1594156                  Textil Copper Andino S.A. [CL/CL]
# 1619350                                    [24] 7.ai, Inc.
# 1812279                                     [24]7.AI, INC.
# 1883872                                 True[X] Media Inc.
# 1907401      BASF Lacke + Farben Aktiengesellschaft[DE/DE]
# 2202444  DIRECTOR GENERAL, DEFENCE RESEARCH & DEVELOPME...
# 2627138  Pacific Biomedical Research, Inc. [Cell Mart, ...
# 3000543                             Generics [UK]  Limited
# 3099386                                   [24] 7 .ai, Inc.
# 3210531  Kinetic Energy Corporation [a wholly owned sub...
# 3943013            Reuter Chemische Apparatebau KG [DE/DE]
# 4148124           Reuter Chemische Apparatebau KG [DE/DE]
# 4174756                           BRY AIR [ASIA] PVT. LTD.
# 4532151        Rand Steel Technology [Proprietary] Limited
# 4958116                P. Robertet & Cie [Societe Anomyme]
# 5895940                          Syminex [Societe Anonyme]
# 6061932                                     [27]7.ai, Inc.
# 6216899                                    [24]7 .AI, INC.
#
#                                              organization3
# 101286                                   Trailmor  Limited
# 114949                                   Generics  Limited
# 273573   GmbH Beratungsunternehmen fr Systeme und Techn...
# 297148                               [X+1] Solutions, Inc.
# 405573                                      [24]7.ai, Inc.
# 477425                                    Generics Limited
# 583327                                      [24]7.AI, Inc.
# 1594156                         Textil Copper Andino S.A.
# 1619350                                    [24] 7.ai, Inc.
# 1812279                                     [24]7.AI, INC.
# 1883872                                 True[X] Media Inc.
# 1907401             BASF Lacke + Farben Aktiengesellschaft
# 2202444  DIRECTOR GENERAL, DEFENCE RESEARCH & DEVELOPME...
# 2627138                 Pacific Biomedical Research, Inc.
# 3000543                                 Generics   Limited
# 3099386                                   [24] 7 .ai, Inc.
# 3210531                        Kinetic Energy Corporation
# 3943013                   Reuter Chemische Apparatebau KG
# 4148124                  Reuter Chemische Apparatebau KG
# 4174756                                 BRY AIR  PVT. LTD.
# 4532151                     Rand Steel Technology  Limited
# 4958116                                 P. Robertet & Cie
# 5895940                                           Syminex
# 6061932                                     [27]7.ai, Inc.
# 6216899                                    [24]7 .AI, INC.

# %%
df2.columns
# Out:
# Index(['assignee_id', 'organization', 'brace', 'bracelen', 'bractext',
#        'organization2', 'organization3', 'brace1', 'bracelen1', 'bractext1'],
#       dtype='object')

# %%
del df2['brace'], df2['bracelen'], df2['brace1'], df2['bracelen1']

# %%
df2.columns
# Out:
# Index(['assignee_id', 'organization', 'bractext', 'organization2',
#        'organization3', 'bractext1'],
#       dtype='object')

# %%
df2['bractext1'].fillna("", inplace = True)

# %%
df2.isna().sum()
# Out:
# assignee_id      0
# organization     0
# bractext         0
# organization2    0
# organization3    0
# bractext1        0
# dtype: int64

# %%
#####################

# %%
df2.columns
# Out:
# Index(['assignee_id', 'organization', 'bractext', 'organization2',
#        'organization3', 'bractext1'],
#       dtype='object')

# %%
#convert to lower case

# %%
df2['orglow'] = df2['organization3'].apply(lambda x: x.lower()) #601225

# %%
df2.orglow.nunique() #601225
# Out:
# 601225

# %%
df2['orglow2'] = df2['orglow'].str.replace("\br&d\b","research and development")
df2['orglow2'] = df2['orglow2'].str.replace("\br & d\b","research and development")

# %%
df2.orglow2.nunique() #601143
# Out:
# 601225

# %%
df2['orglow2'] = df2['orglow2'].str.replace('\.','', regex=True)
df2['orglow2'] = df2['orglow2'].str.replace(',',' ', regex=True)
df2['orglow2'] = df2['orglow2'].str.replace("'",'', regex=True)
df2['orglow2'] = df2['orglow2'].str.replace("/",' ', regex=True)
df2['orglow2'] = df2['orglow2'].str.replace('"','', regex=True)
df2['orglow2'] = df2['orglow2'].str.replace('-',' ', regex=True)
df2['orglow2'] = df2['orglow2'].str.replace('+',' ', regex=True)
df2['orglow2'] = df2['orglow2'].apply(lambda x: x.strip())

# %%
df2.orglow2.nunique() #544223
# Out:
# 544305

# %%
###join single characters
regex = re.compile('(?<![a-zA-Z0-9]{2})(?<=[a-zA-Z0-9]{1}) +(?=[a-zA-Z0-9] |.$)')
df2['orglow2'] = df2['orglow2'].str.replace(regex, "")

# %%
df2['orglow2'].nunique() #541410
# Out:
# 541491

# %%
df2['orglow2'] = df2['orglow2'].str.replace(' +', ' ')
df2['orglow2'].nunique() #504908
# Out:
# 504990

# %%
df2["orglow2"] = df2["orglow2"].str.replace(" univ$",' university')
df2["orglow2"] = df2["orglow2"].str.replace(" univ ",' university ')
df2["orglow2"] = df2["orglow2"].str.replace(" mfg$",' manufacturing')
df2["orglow2"] = df2["orglow2"].str.replace(" mfg ",' manufacturing ')
df2["orglow2"] = df2["orglow2"].str.replace(" mfrs$",' manufacturers')
df2["orglow2"] = df2["orglow2"].str.replace(" mfrs ",' manufacturers ')

# %%
df2.orglow2.nunique() #504355
# Out:
# 504437

# %%
df2['last'] = df2['orglow2'].apply(lambda x: x.split()[-1])

# %%
cnt = df2['last'].value_counts() #kaisha, kaisa

# %%
# cnt[(cnt>20)&(cnt<=23)].index

# %%
df2['orglow3'] = df2['orglow2']

# %%
df2[df2.orglow3.str.endswith(" corportion")]['orglow3']
# Out:
# 7738       international business machines corportion
# 15377                                  emc corportion
# 37732                          nitto denko corportion
# 44217                             schering corportion
# 188444                            broadcom corportion
#                               ...
# 6207869                          mobil oil corportion
# 6214519                        dow corning corportion
# 6240517                          albemarle corportion
# 6301344                united technologies corportion
# 6319922                       smith corona corportion
# Name: orglow3, Length: 182, dtype: object

# %%
compend = ['public limited company','et al','ab', 'ag', 'akteingesellschaft', 'aktiebolag', 'aktiegesellschaft', 'aktiengesellchaft', 
               'aktiengesellschaft', 'aktiengesellshaft', 'aktiengessellschaft','aktiengesselschaft',
             'aktiengsellschaft','aps','arl','as',  'asa','assoc','associates','association',
             'atkiengesellschaft','bv', 'bvba','et cie',
               'sab de cv','limited company'
               'sa de cv',
               'ca','et cie', 'cie', 'cie ltee', '& co', '& c',
               'co', 'co l','comany',
               'cc','comapny','incorporee',
             'company', 'compnay', 'cooperation','coporation', 'coproration', 'cororation', 'corp','corporaiton',
             'corporated','corporatiion', 'corporatioin','corporation', 'corporation', 'corporations',
               'corportion',
            'corporatoin', 'corporaton','corportation','corproation','cooperatieve vennootschap','cv',
               'doo','ec',
               'ehf','ev',
             'gbr','gesmbh','gmbh','hf','ilp','in','inc','incoporated','incorporated','incorporates'
             'incorporation','incorported','ind','international','ip','is','intl','internatinal',
             'kabushiki kaisa','kabushiki kaisha', 'kabushiki kaishi','kabushiki kaisya','kabushikigaisha',
             'kabushikikaisha','kabushiki','kft','kg','kgaa','kk','kommanditgesellschaft','koncernovy podnik',
               'pty lt','pty ltd',
               'lc','lcc',
             'lda','limitada','limite','limited','limitee','limted','limtied','llc','lllp','llp','lp','lt','ltc',
            'ltd','ltda','lte','ltee','mbh','na','narodni podnik','naamloze vennootschap','nv','ohg','oy','oyj',
               'partnership','pc',
             'plc','pllc','podnik','pte','pty','roc','rt','s ar l','sa rl'
               's arl','sa','sarl',
               'sas','sau','sdi','sdn bhd',
             'se','sec','seisakusho','sho','slu','snc','societa per azioni','sp zoo','spa','srl','sro','ssr',
             'sssr','sud','the','ua','ulc','unlimited','vof','vzw','zo o','z oo']

# %%
compend
# Out:
# ['public limited company',
#  'et al',
#  'ab',
#  'ag',
#  'akteingesellschaft',
#  'aktiebolag',
#  'aktiegesellschaft',
#  'aktiengesellchaft',
#  'aktiengesellschaft',
#  'aktiengesellshaft',
#  'aktiengessellschaft',
#  'aktiengesselschaft',
#  'aktiengsellschaft',
#  'aps',
#  'arl',
#  'as',
#  'asa',
#  'assoc',
#  'associates',
#  'association',
#  'atkiengesellschaft',
#  'bv',
#  'bvba',
#  'et cie',
#  'sab de cv',
#  'limited companysa de cv',
#  'ca',
#  'et cie',
#  'cie',
#  'cie ltee',
#  '& co',
#  '& c',
#  'co',
#  'co l',
#  'comany',
#  'cc',
#  'comapny',
#  'incorporee',
#  'company',
#  'compnay',
#  'cooperation',
#  'coporation',
#  'coproration',
#  'cororation',
#  'corp',
#  'corporaiton',
#  'corporated',
#  'corporatiion',
#  'corporatioin',
#  'corporation',
#  'corporation',
#  'corporations',
#  'corportion',
#  'corporatoin',
#  'corporaton',
#  'corportation',
#  'corproation',
#  'cooperatieve vennootschap',
#  'cv',
#  'doo',
#  'ec',
#  'ehf',
#  'ev',
#  'gbr',
#  'gesmbh',
#  'gmbh',
#  'hf',
#  'ilp',
#  'in',
#  'inc',
#  'incoporated',
#  'incorporated',
#  'incorporatesincorporation',
#  'incorported',
#  'ind',
#  'international',
#  'ip',
#  'is',
#  'intl',
#  'internatinal',
#  'kabushiki kaisa',
#  'kabushiki kaisha',
#  'kabushiki kaishi',
#  'kabushiki kaisya',
#  'kabushikigaisha',
#  'kabushikikaisha',
#  'kabushiki',
#  'kft',
#  'kg',
#  'kgaa',
#  'kk',
#  'kommanditgesellschaft',
#  'koncernovy podnik',
#  'pty lt',
#  'pty ltd',
#  'lc',
#  'lcc',
#  'lda',
#  'limitada',
#  'limite',
#  'limited',
#  'limitee',
#  'limted',
#  'limtied',
#  'llc',
#  'lllp',
#  'llp',
#  'lp',
#  'lt',
#  'ltc',
#  'ltd',
#  'ltda',
#  'lte',
#  'ltee',
#  'mbh',
#  'na',
#  'narodni podnik',
#  'naamloze vennootschap',
#  'nv',
#  'ohg',
#  'oy',
#  'oyj',
#  'partnership',
#  'pc',
#  'plc',
#  'pllc',
#  'podnik',
#  'pte',
#  'pty',
#  'roc',
#  'rt',
#  's ar l',
#  'sa rls arl',
#  'sa',
#  'sarl',
#  'sas',
#  'sau',
#  'sdi',
#  'sdn bhd',
#  'se',
#  'sec',
#  'seisakusho',
#  'sho',
#  'slu',
#  'snc',
#  'societa per azioni',
#  'sp zoo',
#  'spa',
#  'srl',
#  'sro',
#  'ssr',
#  'sssr',
#  'sud',
#  'the',
#  'ua',
#  'ulc',
#  'unlimited',
#  'vof',
#  'vzw',
#  'zo o',
#  'z oo']

# %%
def clean(colname, col):

    compend = ['public limited company','et al','ab', 'ag', 'akteingesellschaft', 'aktiebolag', 'aktiegesellschaft', 'aktiengesellchaft', 
               'aktiengesellschaft', 'aktiengesellshaft', 'aktiengessellschaft','aktiengesselschaft',
             'aktiengsellschaft','aps','arl','as',  'asa','assoc','associates','association',
             'atkiengesellschaft','bv', 'bvba','et cie',
               'sab de cv','limited company'
               'sa de cv',
               'ca','et cie', 'cie', 'cie ltee', '& co', '& c',
               'co', 'co l','comany',
               'cc','comapny',
             'company', 'compnay', 'cooperation','coporation', 'coproration', 'cororation', 'corp','corporaiton',
             'corporated','corporatiion', 'corporatioin','corporation', 'corporation', 'corporations',
               'corportion',
            'corporatoin', 'corporaton','corportation','corproation','cooperatieve vennootschap','cv',
               'doo','ec',
               'ehf','ev',
             'gbr','gesmbh','gmbh','hf','ilp','in','inc','incoporated','incorporated','incorporates'
             'incorporation','incorported','ind','international','ip','is','intl','internatinal',
             'kabushiki kaisa','kabushiki kaisha', 'kabushiki kaishi','kabushiki kaisya','kabushikigaisha',
             'kabushikikaisha','kabushiki','kft','kg','kgaa','kk','kommanditgesellschaft','koncernovy podnik',
               'pty lt','pty ltd',
               'lc','lcc',
             'lda','limitada','limite','limited','limitee','limted','limtied','llc','lllp','llp','lp','lt','ltc',
            'ltd','ltda','lte','ltee','mbh','na','narodni podnik','naamloze vennootschap','nv','ohg','oy','oyj',
               'partnership','pc',
             'plc','pllc','podnik','pte','pty','roc','rt','s ar l','sa rl'
               's arl','sa','sarl',
               'sas','sau','sdi','sdn bhd',
             'se','sec','seisakusho','sho','slu','snc','societa per azioni','sp zoo','spa','srl','sro','ssr',
             'sssr','sud','the','ua','ulc','unlimited','vof','vzw','zo o','z oo']  
    
    for each in compend:
        if (len(df2[df2[colname].str.endswith(each)]) >0 ):
            
            print(each,len(df2[df2[colname].str.endswith(each)]) )
            
            y  = " "+each + "$"
            
            df2.loc[df2[colname].str.endswith(each),col] = df2.loc[df2[colname].str.endswith(each),colname].str.replace(y,"")

            df2[col] = df2[col].apply(lambda x: x.strip())
            
#             return (df_corp)

# %%
clean('orglow2','orglow3')
# Out:
# public limited company 120
# et al 91
# ab 7398
# ag 10800
# akteingesellschaft 29
# aktiebolag 682
# aktiegesellschaft 28
# aktiengesellchaft 22
# aktiengesellschaft 1721
# aktiengesellshaft 49
# aktiengessellschaft 45
# aktiengesselschaft 24
# aktiengsellschaft 35
# aps 992
# arl 1017
# as 6798
# asa 189
# assoc 29
# associates 716
# association 244
# atkiengesellschaft 31
# bv 6750
# bvba 216
# et cie 102
# sab de cv 17
# kft 2
# kg 172
# kgaa 5
# kk 95
# kommanditgesellschaft 4
# lc 114
# lcc 5
# lda 14
# limite 1
# limited 1207
# limitee 1
# limted 9
# llc 56
# lllp 49
# llp 705
# lp 100
# lt 773
# ltc 5
# ltd 535
# ltda 2
# lte 39
# ltee 10
# mbh 377
# na 2178
# nv 72
# ohg 11
# oy 590
# oyj 2
# partnership 102
# pc 166
# plc 7
# pllc 1
# pte 1909
# pty 8041
# roc 61
# rt 2571
# sa 3618
# sarl 5
# sas 120
# sau 10
# sdi 57
# se 4299
# sec 108
# seisakusho 731
# sho 564
# snc 23
# societa per azioni 8
# spa 82
# srl 52
# sro 6
# ssr 13
# sud 39
# the 30
# ua 144
# unlimited 242
# vzw 2
# z oo 3

# %%
df2['orglow4'].isna().sum()
# Out:
# 0

# %%
clean('orglow4','orglow4')
# Out:
# ab 1202
# ag 1243
# aktiebolag 3
# aktiengesellschaft 15
# aps 123
# arl 48
# as 2891
# asa 100
# associates 107
# association 1
# bv 26
# ca 5049
# cie 43
# & co 213
# & c 10
# co 5286
# comany 1
# cc 141
# company 235
# compnay 1
# cooperation 1
# corp 285
# corporated 12
# corporation 448
# corporation 274
# corporations 7
# cv 26
# doo 9
# ec 4302
# ev 235
# gbr 5
# gesmbh 7
# gmbh 65
# hf 27
# ilp 2
# in 3605
# inc 131
# incorporated 9
# ind 278
# international 394
# ip 1083
# is 3425
# intl 8
# internatinal 1
# kabushiki kaisha 26
# kabushikikaisha 1
# kft 2
# kg 157
# kgaa 8
# kk 94
# kommanditgesellschaft 2
# lc 90
# lcc 5
# lda 14
# limite 1
# limited 40
# limitee 1
# limted 3
# llc 35
# lllp 3
# llp 3
# lp 91
# lt 787
# ltc 5
# ltd 87
# ltda 1
# lte 38
# ltee 1
# mbh 95
# na 2150
# nv 27
# ohg 8
# oy 430
# partnership 2
# pc 155
# plc 5
# pllc 1
# pte 8
# pty 5
# roc 60
# rt 2579
# sa 3559
# sarl 2
# sas 120
# sau 10
# sdi 11
# se 4256
# sec 102
# seisakusho 32
# sho 560
# snc 22
# societa per azioni 8
# spa 68
# srl 40
# sro 6
# ssr 13
# sud 21
# the 30
# ua 144
# unlimited 1
# vzw 2
# z oo 3

# %%
df2['orglow4'].isna().sum()
# Out:
# 0

# %%
df2['orglow4'].nunique() #443399
# Out:
# 443846

# %%
df2['orglow5'] = df2['orglow4']

# %%
df2[df2.orglow5.str.endswith("illinois")]['orglow5'].unique()
# Out:
# array(['owens illinois',
#        'the board of trustees of the university of illinois',
#        'board of trustees of the university of illinois',
#        'university of illinois', 'the board of trustees of the illinois',
#        'its academic of illinois',
#        'the board of trustrees of the university of illinois',
#        'the board of trustees of university of illinois',
#        'board of trustees of university of illinois',
#        'board of trustees university of illinois',
#        'the board of trustess of the university of illinois',
#        'printpack illinois', 'isotech of illinois',
#        'the board of trustees of the of the university of illinois',
#        'the board of trustees of the universtiy of illinois',
#        'the board of trustees of the univerity of illinois',
#        'the board of trustees of the university of illinois a body corporate and politic of the state of illinois',
#        'maploca of illinois', 'conservation technology of illinois',
#        'the university of illinois',
#        'the board of trustees of the university illinois',
#        'the borad of trustees of the university of illinois',
#        'the board of trustees of the uniersity of illinois',
#        'waste management of illinois',
#        'american cleaning equipment corporation of illinois',
#        'warning lites of illinois',
#        'the board of trustees of the univesity of illinois',
#        'the board of trustees of the unviersity of illinois',
#        'board of trustess of the university of illinois',
#        'teejet technologies illinois',
#        'rosalind franklin university of medicine and science an illinois',
#        'the board of trutees of the university of illinois',
#        'emergency technical services corporation of illinois',
#        'safe air of illinois', 'general telephone of illinois',
#        'board of trustees of the university illinois', 'ceac of illinois',
#        'owen illinois', 'techalloy illinois',
#        'the board of trustees of the univeristy of illinois',
#        'maneely illinois', 'the brands family illinois',
#        'the broad of trustees of the university of illinois',
#        'carry companies of illinois',
#        'the board of trustees if the university of illinois',
#        'the broad of trusstees of the university of illinois',
#        'board of trust of the university of illinois',
#        'the trustees of the university of illinois',
#        'board of trustees the university of illinois',
#        'beck noma illinois',
#        'board of trustees for the university of illinois',
#        'nu life inc of illinois', 'procomm inc of hoopeston illinois',
#        'breeze illinois', 'the board of trustees university of illinois',
#        'bufferad illinois',
#        'the board of trustes of the university of illinois',
#        'the boards of trustees of the university of illinois',
#        'the board of the university of illinois',
#        'the board of trustees of the universiy of illinois',
#        'praxis illinois',
#        'the board of regents of the university of illinois',
#        'kama of illinois', 'press machinery corporation of illinois',
#        'martin equipment of illinois', 'adtech inc of illinois',
#        'the talman home federal savings and loan association of illinois',
#        'the board of trustees of the university of illinois urbana champaign illinois'],
#       dtype=object)

# %%
def geoclean(colname, col):
    
    compend = ['north america','america', 'berlin','denmark','finland','france',
             'il',
             'ind','india','ireland','japan',
             'ky','nederland','new zealand','ny', 'uk','us','usa','italia',"israel", "netherlands","atlanta",
               "pennsylvania","new england" "new holland",'united states'] 

   
    for each in compend:

        if (len(df2[df2[colname].str.endswith(each)]) >0 ):
            
            print(each,len(df2[df2[colname].str.endswith(each)]) )

            y  = " "+each + "$"
            oe = "of "+ each
            ot = 'of the '+ each
            df2.loc[(df2[colname].str.endswith(each))&(~(df2[colname].str.endswith(oe))&(~df2[colname].str.endswith(ot))),
                    col] = df2.loc[(df2[colname].str.endswith(each))&(~(df2[colname].str.endswith(oe))&(~df2[colname].str.endswith(ot))),colname].str.replace(y,"")

            df2[col] = df2[col].apply(lambda x: x.strip())
            
#             return (df_corp)

# %%
geoclean('orglow5','orglow5')
# Out:
# north america 913
# america 2049
# berlin 189
# denmark 69
# finland 125
# france 973
# il 1630
# ind 277
# india 75
# ireland 260
# japan 762
# ky 257
# nederland 202
# new zealand 100
# ny 735
# uk 824
# us 2968
# usa 2783
# italia 544
# israel 274
# netherlands 176
# atlanta 32
# pennsylvania 74
# united states 11

# %%
df2['orglow5'].isna().sum()
# Out:
# 0

# %%
df2.orglow5.nunique() #441065
# Out:
# 441534

# %%
df2[df2['orglow4'].str.endswith("united states")]['orglow5'].unique()
# Out:
# array(['ici', 'wolters kluwer', 'mayreder consult of the united states',
#        'esb', 'nasa an agency of the united states',
#        'sb pharmco puerto rico inc of the united states',
#        'the equitable life assurance society of the united states'],
#       dtype=object)

# %%
df2.orglow5.nunique() #441083
# Out:
# 441534

# %%
df2['orglow6'] = df2['orglow5']

# %%
clean('orglow6','orglow6')
# Out:
# ab 1221
# ag 971
# aktiebolag 3
# aktiengesellschaft 12
# aps 125
# arl 48
# as 2956
# asa 100
# associates 8
# association 1
# bv 20
# ca 3164
# cie 15
# & co 2
# & c 1
# co 5304
# comany 1
# cc 153
# company 54
# cooperation 1
# coporation 1
# corp 296
# corporated 8
# corporation 342
# corporation 276
# corporations 7
# cv 27
# doo 9
# ec 4411
# ev 249
# gbr 5
# gesmbh 7
# gmbh 72
# hf 27
# ilp 2
# in 3526
# inc 143
# incorporated 5
# ind 278
# international 65
# ip 907
# is 3511
# kabushiki kaisha 27
# kabushikikaisha 1
# kabushiki 2
# kft 2
# kg 157
# kgaa 3
# kk 95
# kommanditgesellschaft 2
# lc 97
# lcc 5
# lda 15
# limite 1
# limited 30
# limitee 1
# limted 3
# llc 39
# lllp 3
# llp 3
# lp 94
# lt 802
# ltc 5
# ltd 91
# ltda 1
# lte 39
# ltee 1
# mbh 95
# na 2186
# nv 27
# ohg 8
# oy 435
# partnership 2
# pc 165
# plc 5
# pllc 1
# pte 8
# pty 5
# roc 60
# rt 2611
# sa 891
# sarl 2
# sas 121
# sau 10
# sdi 14
# se 4305
# sec 102
# seisakusho 31
# sho 561
# snc 22
# societa per azioni 8
# spa 68
# srl 40
# sro 6
# ssr 13
# sud 21
# the 38
# ua 148
# ulc 1
# unlimited 1
# vzw 2
# z oo 3

# %%
df2['orglow6'].isna().sum()
# Out:
# 0

# %%
df2.orglow6.nunique() #441329
# Out:
# 441411

# %%
df2['orglow6'] = df2["orglow6"].str.replace("&",' ')
df2['orglow6'] = df2['orglow6'].apply(lambda x: x.strip())
df2['orglow6'] = df2['orglow6'].str.replace(' +', ' ')
regex = re.compile('(?<![a-zA-Z0-9]{2})(?<=[a-zA-Z0-9]{1}) +(?=[a-zA-Z0-9] |.$)')
df2['orglow6'] = df2['orglow6'].str.replace(regex, "")

# %%
df2.orglow6.nunique() #439249
# Out:
# 439606

# %%
df2.columns
# Out:
# Index(['assignee_id', 'organization', 'bractext', 'organization2',
#        'organization3', 'bractext1', 'orglow', 'orglow2', 'last', 'orglow3',
#        'orglow4', 'orglow5', 'orglow6'],
#       dtype='object')

# %%
del  df2['last']

# %%
df2['orglow6'] = df2['orglow6'].apply(lambda x: x.strip())

# %%
df2.orglow6.nunique() #439249
# Out:
# 439606

# %%
df2['last'] = df2['orglow6'].apply(lambda x: x.split()[-1])

# %%
cnt = df2['last'].value_counts()

# %%
df2[df2['last']=="e"][['orglow','orglow5']]
# Out:
#                                                     orglow  \
# 15255    ste d'application plastique, mecanique et elec...
# 55646                                shuang-ho-e co., ltd.
# 100370                    prime research alliance e., inc.
# 123152                     dipl.-ing. schultz, wolfgang e.
# 152803                     prime research alliance e, inc.
# ...                                                    ...
# 5829449                                 at & e corporation
# 5943490                                      sphere e, llc
# 6082676                                    columbus e. aps
# 6201278                          crs srl centro ricerche e
# 6348217                            double e company, inc.
#
#                                                    orglow5
# 15255    ste dapplication plastique mecanique et electr...
# 55646                                          shuang ho e
# 100370                           prime research alliance e
# 123152                         dipl ing schultz wolfgang e
# 152803                           prime research alliance e
# ...                                                    ...
# 5829449                                             at & e
# 5943490                                           sphere e
# 6082676                                         columbus e
# 6201278                          crs srl centro ricerche e
# 6348217                                           double e
#
# [90 rows x 2 columns]

# %%
cnt[(cnt>100)&(cnt<=115)]
# Out:
# information    115
# seal           115
# aircraft       115
# board          114
# safe           114
#               ...
# pa             101
# assets         101
# luxembourg     101
# measurement    101
# direct         101
# Name: last, Length: 66, dtype: int64

# %%
# split

# %%
df2['orglow7'] = df2['orglow6']

# %%
splt = [' gmbh',' corp ',' co ',' limited ',' pty ltd ',' inc '," ab ", " ag ", " ohg ",' company'
        'kabishiki kaisha', 'kabushiki ku kaisha', 'kabnushiki kaisha', 'kab kaisha', ' inc ',' et Compagnie'
         ]
endst = ['ip','die','cokg',' c', 'switzerland', 'texas','deutschland']


for each in splt:
    if (len(df2[df2['orglow7'].str.contains(each)])>0): 
            print(each,len(df2[df2['orglow7'].str.contains(each)]) )
            df2['orglow7'] = df2['orglow7'].apply(lambda x : x.split(each)[0])
            df2['orglow7'] = df2['orglow7'].apply(lambda x: x.strip())

for each in endst:
    if (len(df2[df2['orglow6'].str.endswith(each)])>0): 
            print(each,len(df2[df2['orglow7'].str.endswith(each)]) )
            y = " "+each + "$"
            df2['orglow7'] = df2['orglow7'].apply(lambda x : x.replace(y,""))
            df2['orglow7'] = df2['orglow7'].apply(lambda x: x.strip())
# Out:
#  gmbh 4189
#  corp  241
#  co  1174
#  limited  797
#  pty ltd  44
#  inc  745
#  ab  97
#  ag  732
#  ohg  26
# kabushiki ku kaisha 1
# kabnushiki kaisha 1
# kab kaisha 1
# ip 895
# die 242
# cokg 6
#  c 90
# switzerland 145
# texas 124
# deutschland 472

# %%
df2.loc[df2['orglow7'].str.endswith(" of"),"orglow7"] = df2.loc[df2['orglow7'].str.endswith(" of"),"orglow6"]

# %%
df2.loc[df2['orglow3'].str.endswith(" de france"),"orglow7"] = df2.loc[df2['orglow3'].str.endswith(" de france"),"orglow7"]

# %%
df2.orglow7.nunique()  #435878
# Out:
# 436177

# %%
print(df2.loc[254,'orglow'])
# Out:
# compagnie internationale pour l'informatique cii-honeywell bull

# %%
#split after cii

# %%
for i in df2[df2['orglow7'].str.contains(" cii ")].index:
        df2.loc[i,"orglow7"] = df2.loc[i]["orglow7"].split(" cii ")[-1]

# %%
df2.orglow7.nunique() #435878
# Out:
# 436166

# %%
df2['last'] = df2['orglow7'].apply(lambda x:x.split()[-1])

# %%
df2['orglen'] = df2['orglow7'].apply(lambda x: len(x.split()))

# %%
lst = df2[df2['orglen']>1]['last'].value_counts()

# %%
#mfg to manufacturing; of; ulc,  naamloze vennootschap, cooperatieve vennootschap, et cie, finland, new zealand
#cc, denmark,comapny, il, sdi, arl
# to technology

# %%
lst[(lst>45)&(lst<=50)].index
# Out:
# Index(['processes', 'mines', 'camera', 'diamonds', 'smelting', 'clinic',
#        'merchandising', 'switch', 'nurnberg', 'norway', 'md', 'all',
#        'irrigation', 'produktions', 'clean', 'manfacturing', 'fusion',
#        'washington', 'iron', 'benz', 'squibb', 'lumber', 'white', 'harris',
#        'nutzfahrzeuge', 'braun', 'metallurgie', 'auto', 'antenna', 'vac',
#        'delivery', 'phones', 'city', 'missouri', 'compagnie', 'telegraph',
#        'professional', 'robot', 'scientifiques', 'blue', 'kogaku', 'jet',
#        'vertriebsgesellschaft', 'electronique', 'tactical', 'mechatronics',
#        'biomaterials', 'unico', 'ai', 'tubes', 'screw', 'investors',
#        'northern', '3', 'hall', 'microtechnique', 'seimitsu', 'energia',
#        'crane', 'go', 'jena', 'wind', 'entwicklung', 'garden', 'int',
#        'broadcasting', 'v', 'tecnologia', 'contact', 'doptique', 'tape',
#        'methods', 'south', 'lines', 'island', 'pet', 'kunststoff', 'bath',
#        'sc', 'teknik', 'angeletti', 'shokai', 'beverages', 'francaise',
#        'finishing', 'children'],
#       dtype='object')

# %%
df2[df2['last']=="hk"][['organization','orglow6']]
# Out:
#                                               organization  \
# 72950                              ConvenientPower HK Ltd.
# 118470                               Prime View HK Limited
# 125469                           WOW! CREATIONS HK LIMITED
# 159761                                         MRM HK Ltd.
# 292077                                       CM HK LIMITED
# 313423               BP Children's Product HK Co., Limited
# 529997              BP CHILDREN'S PRODUCTS HK CO., LIMITED
# 562159                                      vitroTV HK Ltd
# 568498                 BP Children's Products HK Co., Ltd.
# 593005               BP Children's Products HK Co. Limited
# 598606                                 Tymphany HK Limited
# 615289              BP Children's Products HK Co., Limited
# 649799                                      MRM HK LIMITED
# 652931                                          H & K Inc.
# 660214                               GS Design HK, Limited
# 673861   Global Advanced Packaging Technology H.K. Limited
# 691234                            Master Brands HK Limited
# 723729                            SAE Magnetics H.K., Ltd.
# 731516                                 TYMPHANY HK LIMITED
# 776629                                 Hydrogen HK Limited
# 988609                 Yiwu Jiangr Bio-Technology HK Corp.
# 1181497                                XIAOMI H.K. LIMITED
# 1523625                                   TYMPHANY HK LTD.
# 1588119                               Kienzle Time HK Ltd.
# 1591127                                 Karp Impex HK Ltd.
# 1724128                        Societe Anonyme H.K. France
# 1728771                     Trend Top International HK Ltd
# 1807083                                  Enterproid HK Ltd
# 2344149                    CREEDON TECHNOLOGIES HK LIMITED
# 2390986                                      CM HK Limited
# 2519847                                      Dansk HK Ltd.
# 2665109                                    Cray HK Limited
# 2737160                                     MRM HK Limited
# 3170624                             CYWEEMOTION HK LIMITED
# 3252374                       SCANAVO MANUFACTURING HK LTD
# 3418340                                Xiaomi H.K. Limited
# 3565018                       Societe Anonyme H. K. France
# 3720962                  Sol-Millennium Medical HK Limited
# 3817766                                   Xiaomi H.K. Ltd.
# 2969845                          british telecommuncations
# 3227313                         british telecommunications
# 3469411   british telecommunications public limited comany
# 3472547  british telecommunications a public limited co...
# 3549403   british telecommunictions public limited company
# 3666998   british telecommunicatons public limited company
# 3858004          british telecommunications public limited
# 3887883  british telecommunications public limited company
# 4402278                     british telecommunications plc
# 4480622             british telecommunications corporation
# 4705575  british telecommunications puplic limited company
# 4879126            british telecommunications public ltdco
# 4928128  british telecommunications public limited company
# 4962633   british telecommunications pubic limited company
# 4965205      united kingdom and british telecommunications
# 5015353                     british telecommunications plc
# 5347127  british telecommunications public limited company
# 5493236   british telecommnications public limited company
# 5528669   british telecommunicaions public limited company
# 5816842                  british telecommunications public
# 6078206  british telecommunications public) limited com...
# 6351611                      british telecommuncations plc
# 6355836  british telecommunications public limited company
#
#                                                    orglow3  \
# 836              british telecommunications public limited
# 5993                             british telecommuncations
# 18619                           british telecommunications
# 32141            british telecommunications public limited
# 53185                           british telecommunications
# 53366            british telecommunications public limited
# 70120            british telecommunications public limited
# 88593            british telecommunications public limited
# 238057                          british telecommunications
# 268546           british telecommunications public company
# 497848           british telecommunications public limited
# 516326                          british telecommunications
# 583946            british telecommunication public limited
# 635743            british telecomunications public limited
# 704296           british telecommunications public limited
# 720817   khalifa university of science technology and r...
# 1028455         british telecommunicatioins public limited
# 1045141                          british telecommunication
# 1175860           british telecommunicatons public limited
# 1196828  british telecommunications public limited comp...
# 1322221                         british telecommunications
# 1376766          british telecommunications public limited
# 1556032          british telecommunications public limited
# 1654844                         british telecommunications
# 1665551                         british telecommunications
# 1797787           british telecommunication public limited
# 1824277           british telecommunication public limited
# 1915062          british telecommunications public limited
# 2059800                         british telecommunications
# 2141364                         british telecommunications
# 2300936          british telecommunicaitons public limited
# 2422571           british telecommnications public limited
# 2532673                          british telecommunication
# 2829345          british telecommunications public limited
# 2969845                          british telecommuncations
# 3227313                         british telecommunications
# 3469411          british telecommunications public limited
# 3472547        british telecommunications a public limited
# 3549403           british telecommunictions public limited
# 3666998           british telecommunicatons public limited
# 3858004                  british telecommunications public
# 3887883          british telecommunications public limited
# 4402278                         british telecommunications
# 4480622                         british telecommunications
# 4705575          british telecommunications puplic limited
# 4879126            british telecommunications public ltdco
# 4928128          british telecommunications public limited
# 4962633           british telecommunications pubic limited
# 4965205      united kingdom and british telecommunications
# 5015353                         british telecommunications
# 5347127          british telecommunications public limited
# 5493236           british telecommnications public limited
# 5528669           british telecommunicaions public limited
# 5816842                  british telecommunications public
# 6078206         british telecommunications public) limited
# 6351611                          british telecommuncations
# 6355836          british telecommunications public limited
#
#                                                    orglow4  \
# 836                      british telecommunications public
# 5993                             british telecommuncations
# 18619                           british telecommunications
# 32141                    british telecommunications public
# 53185                           british telecommunications
# 53366                    british telecommunications public
# 70120                    british telecommunications public
# 88593                    british telecommunications public
# 238057                          british telecommunications
# 268546                   british telecommunications public
# 497848                   british telecommunications public
# 516326                          british telecommunications
# 583946                    british telecommunication public
# 635743                    british telecomunications public
# 704296                   british telecommunications public
# 720817   khalifa university of science technology and r...
# 1028455                 british telecommunicatioins public
# 1045141                          british telecommunication
# 1175860                   british telecommunicatons public
# 1196828  british telecommunications public limited comp...
# 1322221                         british telecommunications
# 1376766                  british telecommunications public
# 1556032                  british telecommunications public
# 1654844                         british telecommunications
# 1665551                         british telecommunications
# 1797787                   british telecommunication public
# 1824277                   british telecommunication public
# 1915062                  british telecommunications public
# 2059800                         british telecommunications
# 2141364                         british telecommunications
# 2300936                  british telecommunicaitons public
# 2422571                   british telecommnications public
# 2532673                          british telecommunication
# 2829345                  british telecommunications public
# 2969845                          british telecommuncations
# 3227313                         british telecommunications
# 3469411                  british telecommunications public
# 3472547                british telecommunications a public
# 3549403                   british telecommunictions public
# 3666998                   british telecommunicatons public
# 3858004                  british telecommunications public
# 3887883                  british telecommunications public
# 4402278                         british telecommunications
# 4480622                         british telecommunications
# 4705575                  british telecommunications puplic
# 4879126            british telecommunications public ltdco
# 4928128                  british telecommunications public
# 4962633                   british telecommunications pubic
# 4965205      united kingdom and british telecommunications
# 5015353                         british telecommunications
# 5347127                  british telecommunications public
# 5493236                   british telecommnications public
# 5528669                   british telecommunicaions public
# 5816842                  british telecommunications public
# 6078206                 british telecommunications public)
# 6351611                          british telecommuncations
# 6355836                  british telecommunications public
#
#                                                    orglow5  \
# 836                      british telecommunications public
# 5993                             british telecommuncations
# 18619                           british telecommunications
# 32141                    british telecommunications public
# 53185                           british telecommunications
# 53366                    british telecommunications public
# 70120                    british telecommunications public
# 88593                    british telecommunications public
# 238057                          british telecommunications
# 268546                   british telecommunications public
# 497848                   british telecommunications public
# 516326                          british telecommunications
# 583946                    british telecommunication public
# 635743                    british telecomunications public
# 704296                   british telecommunications public
# 720817   khalifa university of science technology and r...
# 1028455                 british telecommunicatioins public
# 1045141                          british telecommunication
# 1175860                   british telecommunicatons public
# 1196828  british telecommunications public limited comp...
# 1322221                         british telecommunications
# 1376766                  british telecommunications public
# 1556032                  british telecommunications public
# 1654844                         british telecommunications
# 1665551                         british telecommunications
# 1797787                   british telecommunication public
# 1824277                   british telecommunication public
# 1915062                  british telecommunications public
# 2059800                         british telecommunications
# 2141364                         british telecommunications
# 2300936                  british telecommunicaitons public
# 2422571                   british telecommnications public
# 2532673                          british telecommunication
# 2829345                  british telecommunications public
# 2969845                          british telecommuncations
# 3227313                         british telecommunications
# 3469411                  british telecommunications public
# 3472547                british telecommunications a public
# 3549403                   british telecommunictions public
# 3666998                   british telecommunicatons public
# 3858004                  british telecommunications public
# 3887883                  british telecommunications public
# 4402278                         british telecommunications
# 4480622                         british telecommunications
# 4705575                  british telecommunications puplic
# 4879126            british telecommunications public ltdco
# 4928128                  british telecommunications public
# 4962633                   british telecommunications pubic
# 4965205      united kingdom and british telecommunications
# 5015353                         british telecommunications
# 5347127                  british telecommunications public
# 5493236                   british telecommnications public
# 5528669                   british telecommunicaions public
# 5816842                  british telecommunications public
# 6078206                 british telecommunications public)
# 6351611                          british telecommuncations
# 6355836                  british telecommunications public
#
#                                                    orglow6  \
# 836                      british telecommunications public
# 5993                             british telecommuncations
# 18619                           british telecommunications
# 32141                    british telecommunications public
# 53185                           british telecommunications
# 53366                    british telecommunications public
# 70120                    british telecommunications public
# 88593                    british telecommunications public
# 238057                          british telecommunications
# 268546                   british telecommunications public
# 497848                   british telecommunications public
# 516326                          british telecommunications
# 583946                    british telecommunication public
# 635743                    british telecomunications public
# 704296                   british telecommunications public
# 720817   khalifa university of science technology and r...
# 1028455                 british telecommunicatioins public
# 1045141                          british telecommunication
# 1175860                   british telecommunicatons public
# 1196828  british telecommunications public limited comp...
# 1322221                         british telecommunications
# 1376766                  british telecommunications public
# 1556032                  british telecommunications public
# 1654844                         british telecommunications
# 1665551                         british telecommunications
# 1797787                   british telecommunication public
# 1824277                   british telecommunication public
# 1915062                  british telecommunications public
# 2059800                         british telecommunications
# 2141364                         british telecommunications
# 2300936                  british telecommunicaitons public
# 2422571                   british telecommnications public
# 2532673                          british telecommunication
# 2829345                  british telecommunications public
# 2969845                          british telecommuncations
# 3227313                         british telecommunications
# 3469411                  british telecommunications public
# 3472547                british telecommunications a public
# 3549403                   british telecommunictions public
# 3666998                   british telecommunicatons public
# 3858004                  british telecommunications public
# 3887883                  british telecommunications public
# 4402278                         british telecommunications
# 4480622                         british telecommunications
# 4705575                  british telecommunications puplic
# 4879126            british telecommunications public ltdco
# 4928128                  british telecommunications public
# 4962633                   british telecommunications pubic
# 4965205      united kingdom and british telecommunications
# 5015353                         british telecommunications
# 5347127                  british telecommunications public
# 5493236                   british telecommnications public
# 5528669                   british telecommunicaions public
# 5816842                  british telecommunications public
# 6078206                 british telecommunications public)
# 6351611                          british telecommuncations
# 6355836                  british telecommunications public
#
#                        last  \
# 836                  public
# 5993      telecommuncations
# 18619    telecommunications
# 32141                public
# 53185    telecommunications
# 53366                public
# 70120                public
# 88593                public
# 238057   telecommunications
# 268546               public
# 497848               public
# 516326   telecommunications
# 583946               public
# 635743               public
# 704296               public
# 720817   telecommunications
# 1028455              public
# 1045141   telecommunication
# 1175860              public
# 1196828              public
# 1322221  telecommunications
# 1376766              public
# 1556032              public
# 1654844  telecommunications
# 1665551  telecommunications
# 1797787              public
# 1824277              public
# 1915062              public
# 2059800  telecommunications
# 2141364  telecommunications
# 2300936              public
# 2422571              public
# 2532673   telecommunication
# 2829345              public
# 2969845   telecommuncations
# 3227313  telecommunications
# 3469411              public
# 3472547              public
# 3549403              public
# 3666998              public
# 3858004              public
# 3887883              public
# 4402278  telecommunications
# 4480622  telecommunications
# 4705575              puplic
# 4879126               ltdco
# 4928128              public
# 4962633               pubic
# 4965205  telecommunications
# 5015353  telecommunications
# 5347127              public
# 5493236              public
# 5528669              public
# 5816842              public
# 6078206             public)
# 6351611   telecommuncations
# 6355836              public
#
#                                                    orglow7  orglen
# 836                      british telecommunications public       3
# 5993                             british telecommuncations       2
# 18619                           british telecommunications       2
# 32141                    british telecommunications public       3
# 53185                           british telecommunications       2
# 53366                    british telecommunications public       3
# 70120                    british telecommunications public       3
# 88593                    british telecommunications public       3
# 238057                          british telecommunications       2
# 268546                   british telecommunications public       3
# 497848                   british telecommunications public       3
# 516326                          british telecommunications       2
# 583946                    british telecommunication public       3
# 635743                    british telecomunications public       3
# 704296                   british telecommunications public       3
# 720817   khalifa university of science technology and r...       9
# 1028455                 british telecommunicatioins public       3
# 1045141                          british telecommunication       2
# 1175860                   british telecommunicatons public       3
# 1196828                  british telecommunications public       3
# 1322221                         british telecommunications       2
# 1376766                  british telecommunications public       3
# 1556032                  british telecommunications public       3
# 1654844                         british telecommunications       2
# 1665551                         british telecommunications       2
# 1797787                   british telecommunication public       3
# 1824277                   british telecommunication public       3
# 1915062                  british telecommunications public       3
# 2059800                         british telecommunications       2
# 2141364                         british telecommunications       2
# 2300936                  british telecommunicaitons public       3
# 2422571                   british telecommnications public       3
# 2532673                          british telecommunication       2
# 2829345                  british telecommunications public       3
# 2969845                          british telecommuncations       2
# 3227313                         british telecommunications       2
# 3469411                  british telecommunications public       3
# 3472547                british telecommunications a public       4
# 3549403                   british telecommunictions public       3
# 3666998                   british telecommunicatons public       3
# 3858004                  british telecommunications public       3
# 3887883                  british telecommunications public       3
# 4402278                         british telecommunications       2
# 4480622                         british telecommunications       2
# 4705575                  british telecommunications puplic       3
# 4879126            british telecommunications public ltdco       4
# 4928128                  british telecommunications public       3
# 4962633                   british telecommunications pubic       3
# 4965205      united kingdom and british telecommunications       5
# 5015353                         british telecommunications       2
# 5347127                  british telecommunications public       3
# 5493236                   british telecommnications public       3
# 5528669                   british telecommunicaions public       3
# 5816842                  british telecommunications public       3
# 6078206                 british telecommunications public)       3
# 6351611                          british telecommuncations       2
# 6355836                  british telecommunications public       3

# %%
splt = ['sl','gmbh','companies','pvt','private','co','ag','ip','company','sp',
        'sa rl','et',
       'societa consortile per azioni','gmbh u','hb','et m','hk','incorp',
       'public limited company']

for each in splt:
    y = " "+ each + "$"
    df2['orglow7'] = df2['orglow7'].str.replace(y,"")

# %%
df2['orglow7'] = df2['orglow7'].str.replace("incorporated$","")
df2['orglow7'] = df2['orglow7'].str.replace("corporated$","")

# %%
########first#########

# %%
df2[df2.orglow7.str.endswith("technolgy")]
# Out:
#                       assignee_id  \
# 469408   org_DMu8NH1j9MVIxDJBSQjQ
# 520114   org_m1wjmqxUyvyUHgBZoadC
# 528948   org_1XEPONiowauaN4VG5FNN
# 547020   org_NTtD1DcRfYUaAKesU3t8
# 584799   org_rnddWFedUWaEyFCXXTP3
# ...                           ...
# 6057680  org_0GC3A8lEiDv12UcxiylW
# 6140461  org_5TjGMsLVqdRFjaIiUNoS
# 6277130  org_189EkbiT2zT7L1wyvLxY
# 6345328  org_hBWRkvtFeXFzoaFptnza
# 6364330  org_VMc1FIhBHkZAEvmjS1Kq
#
#                                              organization     bractext  \
# 469408               Massachusetts Institute of Technolgy
# 520114              Sasol Technolgy (Proprietary) Limited  Proprietary
# 528948                              Cisco Technolgy, Inc.
# 6364330   advanced mobile telecommunication technolgy
#
#                                               orglow5  \
# 469408           massachusetts institute of technolgy
# 520114                                sasol technolgy
# 528948                                cisco technolgy
# 547020                              lavenir technolgy
# 584799   union carbide chemicals & plastics technolgy
# ...                                               ...
# 6057680                                avid technolgy
# 6140461                           microsoft technolgy
# 6277130             owens corning fiberglas technolgy
# 6345328                            wuxi wio technolgy
# 6364330   advanced mobile telecommunication technolgy
#
#                                              orglow6       last  \
# 469408          massachusetts institute of technolgy  technolgy
# 520114                               sasol technolgy  technolgy
# 528948                               cisco technolgy  technolgy
# 547020                             lavenir technolgy  technolgy
# 584799    union carbide chemicals plastics technolgy  technolgy
# ...                                              ...        ...
# 6057680                               avid technolgy  technolgy
# 6140461                          microsoft technolgy  technolgy
# 6277130            owens corning fiberglas technolgy  technolgy
# 6345328                           wuxi wio technolgy  technolgy
# 6364330  advanced mobile telecommunication technolgy  technolgy
#
#                                              orglow7  orglen
# 469408          massachusetts institute of technolgy       4
# 520114                               sasol technolgy       2
# 528948                               cisco technolgy       2
# 547020                             lavenir technolgy       2
# 584799    union carbide chemicals plastics technolgy       5
# ...                                              ...     ...
# 6057680                               avid technolgy       2
# 6140461                          microsoft technolgy       2
# 6277130            owens corning fiberglas technolgy       4
# 6345328                           wuxi wio technolgy       3
# 6364330  advanced mobile telecommunication technolgy       4
#
# [62 rows x 15 columns]

# %%
df2['orglow7'] = df2['orglow7'].str.replace("technolgy","technology")

# %%
df2['orglow7'].nunique() #435715
# Out:
# 435716

# %%
df2['first'] = df2['orglow7'].apply(lambda x: x.split()[0])

# %%
cnt = df2['first'].value_counts()

# %%
cnt[(cnt>180)&(cnt<=200)]
# Out:
# solvay         200
# northern       199
# big            199
# agfa           199
# total          199
# solar          197
# health         195
# imperial       194
# xiamen         193
# le             193
# x              192
# henkel         192
# metal          192
# mobile         191
# sk             191
# specialty      191
# rhone          190
# boehringer     189
# deutsches      189
# safety         189
# nederlandse    189
# computer       189
# automated      188
# star           188
# brown          187
# baker          186
# dong           186
# oxford         186
# alfa           185
# medtronic      184
# showa          184
# parker         184
# gd             183
# seiko          182
# g              182
# Name: first, dtype: int64

# %%
len(df2[df2['orglow7'].str.startswith("the")]) >0
# Out:
# True

# %%
lst = ['the', "kabushiki gaisha" , "kabushiki kaisha", "oy", "sa","nv",'aktiebolaget']

for i in lst:
    
    if len(df2[df2['orglow7'].str.startswith("the")])>0:
        print(i,len(df2[df2['orglow7'].str.startswith(i)]))
        y = '^' + i+" "
        df2['orglow7'] = df2['orglow7'].str.replace(y,"")
# Out:
# the 12693
# kabushiki gaisha 13
# kabushiki kaisha 2040
# oy 362
# sa 9154
# nv 298
# aktiebolaget 145

# %%
df2['orglow7'].isna().sum()
# Out:
# 0

# %%
###join single characters
regex = re.compile('(?<![a-zA-Z0-9]{2})(?<=[a-zA-Z0-9]{1}) +(?=[a-zA-Z0-9] |.$)')
df2['orglow7'] = df2['orglow7'].str.replace(regex, "")
df2['orglow7'] = df2['orglow7'].apply(lambda x: x.strip())

# %%
df2['orglow7'].nunique() #432466
# Out:
# 432728

# %%
df2.columns
# Out:
# Index(['assignee_id', 'organization', 'bractext', 'organization2',
#        'organization3', 'bractext1', 'orglow', 'orglow2', 'orglow3', 'orglow4',
#        'orglow5', 'orglow6', 'last', 'orglow7', 'orglen', 'first'],
#       dtype='object')

# %%
del df2['first'], df2['orglen']

# %%
df2['orglow8'] = df2['orglow7']

# %%
df2['orglow8'] = df2['orglow8'].str.replace("telefonaktiebolaget","telephone")
df2['orglow8'] = df2['orglow8'].str.replace(r'(\bat\b\s*\bt\b)', 'att',regex=True)
df2['orglow8'] = df2['orglow8'].str.replace(" and "," ")
df2['orglow8'] = df2['orglow8'].str.replace(" and$","")
df2['orglow8'] = df2['orglow8'].str.replace(" labs$"," laboratories")
df2['orglow8'] = df2['orglow8'].str.replace(" labs "," laboratories ")
df2['orglow8'] = df2['orglow8'].str.replace(" lab$"," laboratory")
df2['orglow8'] = df2['orglow8'].str.replace(" lab "," laboratory ")
df2['orglow8'] = df2['orglow8'].str.replace(" tele communications$"," telecommunications")
df2['orglow8'] = df2['orglow8'].str.replace(" tele communications "," telecommunications ")
df2['orglow8'] = df2['orglow8'].str.replace(" telecom$"," telecommunications")
df2['orglow8'] = df2['orglow8'].str.replace(" bros$"," brothers")
df2['orglow8'] = df2['orglow8'].str.replace(" ill "," illinois ")
df2['orglow8'] = df2['orglow8'].apply(lambda x: x.strip())

# %%
df2['orglow8'] = df2['orglow8'].str.replace(" telecom$"," telecommunications")

# %%
df2[df2.orglow8.str.endswith(" telecom")]
# Out:
# Empty DataFrame
# Columns: [assignee_id, organization, bractext, organization2, organization3, bractext1, orglow, orglow2, orglow3, orglow4, orglow5, orglow6, last, orglow7, orglow8]
# Index: []

# %%
df2.orglow8.nunique() #430290
# Out:
# 430525

# %%
df2['orglow9'] = df2['orglow8']

# %%
# lst = ["8  8, Inc.", "8 x 8, Inc.", '8.times.8 Inc.',
#        '8.times.8, Inc.', '8.times.8, Inc.','8x8, Inc', '8x8, Inc.','88, Inc', '88, Inc.']

# df2.loc[df2['organization'].isin(lst),"orglow9"] = "8times8"

# %%
df2[df2.orglow9.str.contains("international tel")]
# Out:
#                       assignee_id  \
# 285      org_U2TRh9WomWWWDaH5ybhG
# 1640     org_U2TRh9WomWWWDaH5ybhG
# 16821    org_qEk3LlB6IHFyTEuk6fZa
# 66015    org_xfDxYDHkMr76Jk43Pn0f
# 89140    org_uk6w4xkwHSR1q7LAPoYr
# 95522    org_U2TRh9WomWWWDaH5ybhG
# 212768   org_U2TRh9WomWWWDaH5ybhG
# 227458   org_U2TRh9WomWWWDaH5ybhG
# 291822   org_CXOQeXWZBbtSZa7UbbCW
# 413734   org_U2TRh9WomWWWDaH5ybhG
# 572073   org_EusYgAqnybWwLLI27Zvy
# 699511   org_jLtJU5S9ukF7mA5HuhBp
# 976471   org_njVOSoE5NLdanG22dGZh
# 1023559  org_TgTwEpjqMY0TTknpoUWg
egraph
# 16821                international teletext communications
# 66015                      international telecommunication
# 89140                            international teleservice
# 95522                    international telephone telegraph
# 212768                   international telephone telegraph
# 227458                   international telephone telegraph
# 291822                           international telesystems
# 413734                   international telephone telegraph
# 572073                              international tel data
# 699511                           international telesystems
# 976471                               international teldata
# 1023559  open joint stock company long distance interna...
# 1063323                    it international telcom holding
# 1136158                   corabi international telemetrics
# 1185194                           international teldata ii
# 1211897                   international telephone telegram
# 1235285                  international telephone telegraph
# 1296528                          international telesystems
# 1304041                         international telepresence
# 1365605                   international telephone telegrah
# 1507573                              international teldata
# 1535548                              international teldata
# 1811843                          international teleservice
# 2523829                           international telecharge
# 2666761                  international telephone telegraph
# 2866964                          international teleservice
# 2871442       international telephone telegraph industries
# 3701202                  international telephone telegraph
# 3712751                          international tele marine
# 3810230  bao tong international telecommunication holdings
# 3875266  international telecommunications satellite org...
# 3900046                         international telepresence
# 4037003  international telecommunications satellite org...
# 4390550                    international telecommunication
# 4792373                      mb international telecom cabs
# 4964435                  international telephone telegraph
# 5350876         international telecommunications satellite
#
#                                                    orglow9
# 285                      international telephone telegraph
# 1640                     international telephone telegraph
# 16821                international teletext communications
# 66015                      international telecommunication
# 89140                            international teleservice
# 95522                    international telephone telegraph
# 212768                   international telephone telegraph
# 227458                   international telephone telegraph
# 291822                           international telesystems
# 413734                   international telephone telegraph
# 572073                              international tel data
# 699511                           international telesystems
# 976471                               international teldata
# 1023559  open joint stock company long distance interna...
# 1063323                    it international telcom holding
# 1136158                   corabi international telemetrics
# 1185194                           international teldata ii
# 1211897                   international telephone telegram
# 1235285                  international telephone telegraph
# 1296528                          international telesystems
# 1304041                         international telepresence
# 1365605                   international telephone telegrah
# 1507573                              international teldata
# 1535548                              international teldata
# 1811843                          international teleservice
# 2523829                           international telecharge
# 2666761                  international telephone telegraph
# 2866964                          international teleservice
# 2871442       international telephone telegraph industries
# 3701202                  international telephone telegraph
# 3712751                          international tele marine
# 3810230  bao tong international telecommunication holdings
# 3875266  international telecommunications satellite org...
# 3900046                         international telepresence
# 4037003  international telecommunications satellite org...
# 4390550                    international telecommunication
# 4792373                      mb international telecom cabs
# 4964435                  international telephone telegraph
# 5350876         international telecommunications satellite

# %%
df2.loc[df2['orglow9'].str.contains("communications satellite"), "orglow9"] = "comsat"
df2.loc[df2['orglow9'].str.contains("general refractories"), "orglow9"] = "grefco"
df2.loc[df2['orglow9'].str.contains("american colloid"), "orglow9"] = "amcol"
df2.loc[df2['orglow9'].str.contains("aluminum company of america"), "orglow9"] = "alcoa"
df2.loc[df2['orglow9'].str.contains("minnesota min"), "orglow9"] = "3m"
df2.loc[df2['orglow9'].str.contains("3m innovative"), "orglow9"] = "3m"
df2['orglow9'] = df2['orglow9'].str.replace(" comm$"," communications")
# df2['orglow9'] = df2['orglow9'].str.replace("united states", "us")
df2.loc[df2['organization'].str.contains("Tampa Electric Company"), "orglow9"]= "teco"
df2['orglow9'] = df2['orglow9'].str.replace("america online", "aol")
df2['orglow9'] = df2['orglow9'].str.replace("atlantic richfield", "arco")
df2['orglow9'] = df2['orglow9'].str.replace("advanced technology material", "atmi")
df2.loc[df2['organization']=="Bell Canada","orglow9"] = "bce"
df2.loc[df2['organization']=="Bucklee-Mears Company","orglow9"] = "bmc"
df2.loc[df2['orglow9'].str.contains("federal national mortgage"), "orglow9"] = "fannie mae"
df2.loc[df2['orglow9'].str.contains("bt group"), "orglow9"] = "british telecommunications group"
df2.loc[df2['orglow9'].str.contains("crutcher resources"), "orglow9"] = "crc"
df2.loc[df2['orglow9'].str.contains("ecolab"), "orglow9"] = "economics laboratory"
df2.loc[df2['orglow9'].str.contains("educational computer"), "orglow9"] = "ecc"
df2.loc[df2['orglow9'].str.contains("electromagnetic sciences"), "orglow9"] = "ems"
df2.loc[df2['orglow9'].str.contains(" nec "), "orglow9"] = "nippon electric"
df2.loc[df2['orglow9'].str.contains("^nec "), "orglow9"] = "nippon electric"
df2.loc[df2['orglow9'].str.contains(" nec$"), "orglow9"] = "nippon electric"
df2.loc[df2['orglow9'].str.contains("^nec$"), "orglow9"] = "nippon electric"

df2.loc[df2['orglow9'].str.contains("netapp"), "orglow9"] = "network appliance"
df2.loc[df2['orglow9'].str.contains("nortel"), "orglow9"] = "northern telecommunication"
df2.loc[df2['orglow9'].str.contains("sgs thomson microele"), "orglow9"] = "stmicroelectronics"
df2.loc[df2['orglow9'].str.contains("southwest securities"), "orglow9"] = "sws"
df2.loc[df2['orglow9'].str.contains("tdk electronics"), "orglow9"] = "tokyo denki kagaku"
df2.loc[df2['orglow9'].str.contains("tesco"), "orglow9"] = "transnational energy systems"
df2.loc[df2['orglow9'].str.contains("ual corp"), "orglow9"] = "united airlines"
df2.loc[df2['orglow9'].str.contains("usg corp"), "orglow9"] = "united states gypsum"
df2.loc[df2['orglow9'].str.contains("^usf "), "orglow9"] = "usfreightways"
df2.loc[df2['orglow9'].str.contains(" usf$"), "orglow9"] = "usfreightways"
df2.loc[df2['orglow9'].str.contains(" usf "), "orglow9"] = "usfreightways"
df2.loc[df2['organization'].str.contains("Stec "), "orglow9"] = "simpletech"
df2.loc[df2['organization'].str.contains("NNA/S"), "orglow9"] = "novo nordisk"
df2.loc[df2['orglow9'].str.contains("fedex"), "orglow9"] = "federal express"
df2.loc[df2['organization'].str.contains("NMS Communications Corporation"), "orglow9"] = "natural microsystems"
df2['orglow9'] = df2['orglow9'].str.replace("gatx","general american transporation")
df2.loc[df2['organization'].str.contains("ITT Corporation"), "orglow9"] = "international telephone telegraph"
df2.loc[df2['orglow9'].str.contains("wabtec corp "), "orglow9"] = "westinghouse air brake technologies"

df2.loc[df2['orglow9'].str.contains("rhone poulenc"), "orglow9"] = "rhone poulenc"
df2.loc[df2['organization'].str.contains("IT&T Industries, Inc."), "orglow9"] = "international telephone telegraph"

df2.loc[df2['orglow9'].str.contains("alcatel"), "orglow9"] = "alcatel"

# %%
df2.loc[df2['organization']=="Bell Canada","orglow9"] = "bce"

# %%
# del df2['last']

# %%
df2.nunique()
# Out:
# assignee_id      436099
# organization     677775
# bractext           4316
# organization2    675757
# organization3    675748
# bractext1            16
# orglow           601225
# orglow2          504437
# orglow3          459542
# orglow4          443846
# orglow5          441534
# orglow6          439606
# last             136108
# orglow7          432728
# orglow8          430525
# orglow9          429996
# dtype: int64

# %%
df2.orglow9.nunique() #430358
# Out:
# 429996

# %%
########join for patents########

# %%
df_corp = df_corp.drop_duplicates(keep = 'first')
df_corp['organization'] = df_corp['organization'].str.encode('ascii', 'ignore').str.decode('ascii')

# %%
pv = pd.merge(df_corp, df2, left_on = ["assignee_id","organization"], 
              right_on = ["assignee_id","organization"], 
              how = "left")

# %%
pv.nunique() #430358
# Out:
# patent_id        6070872
# assignee_id       436099
# type                   2
# organization      677775
# sequence              16
# bractext            4316
# organization2     675757
# organization3     675748
# bractext1             16
# orglow            601225
# orglow2           504437
# orglow3           459542
# orglow4           443846
# orglow5           441534
# orglow6           439606
# last              136108
# orglow7           432728
# orglow8           430525
# orglow9           429996
# dtype: int64

# %%
pv.isna().sum()
# Out:
# patent_id        0
# assignee_id      0
# type             0
# organization     0
# sequence         0
# bractext         0
# organization2    0
# organization3    0
# bractext1        0
# orglow           0
# orglow2          0
# orglow3          0
# orglow4          0
# orglow5          0
# orglow6          0
# last             0
# orglow7          0
# orglow8          0
# orglow9          0
# dtype: int64

# %%
pv['orglow9'] = pv['orglow9'].str.replace("wm wrigley", "william wrigley")

# %%
#############################

# %%
pv.columns
# Out:
# Index(['patent_id', 'assignee_id', 'type', 'organization', 'sequence',
#        'bractext', 'organization2', 'organization3', 'bractext1', 'orglow',
#        'orglow2', 'orglow3', 'orglow4', 'orglow5', 'orglow6', 'last',
#        'orglow7', 'orglow8', 'orglow9'],
#       dtype='object')

# %%
pv[pv['organization'].str.contains("AT&T")]
# Out:
#         patent_id               assignee_id  type  \
# 231       9565216  org_pSsLdPF4NrnYVGt5DrRI     2
# 266       8631163  org_pSsLdPF4NrnYVGt5DrRI     2
# 312       4635263  org_V1tOidwicuoWA736DE99     2
# 867       5257339  org_V1tOidwicuoWA736DE99     2
# 1377      9503684  org_pSsLdPF4NrnYVGt5DrRI     2
# ...           ...                       ...   ...
# 6257103   7990848  org_pSsLdPF4NrnYVGt5DrRI     2
# 6257364   9848433  org_cqRqlQk0xbkxrNakdlEB     2
# 6257673   7715412  org_tBdNUkbblSIviAl1Vcj9     2
# 6258093   9781184  org_cqRqlQk0xbkxrNakdlEB     2
# 6258130   5513247  org_tBdNUkbblSIviAl1Vcj9     2
#
#                                 organization  sequence bractext  \
# 231       AT&T INTELLECTUAL PROPERTY I, L.P.         0
# 266      AT&T Intellectual Property II, L.P.         0
# 312                   AT&T Bell Laboratories         0
# 867                   AT&T Bell Laboratories         0
# 1377     AT&T Intellectual Property II, L.P.         0
# ...                                      ...       ...      ...
# 6257103  AT&T Intellectual Property II, L.P.         0
# 6257364                 AT&T Mobility II LLC         1
# 6257673                           AT&T Corp.         0
# 6258093                 AT&T MOBILITY II LLC         0
# 6258130                           AT&T Corp.         0
#
#                                organization2  \
# 231       AT&T INTELLECTUAL PROPERTY I, L.P.
# 266      AT&T Intellectual Property II, L.P.
# 312                   AT&T Bell Laboratories
# 867                   AT&T Bell Laboratories
# 1377     AT&T Intellectual Property II, L.P.
# ...                                      ...
# 6257103  AT&T Intellectual Property II, L.P.
# 6257364                 AT&T Mobility II LLC
# 6257673                           AT&T Corp.
# 6258093                 AT&T MOBILITY II LLC
# 6258130                           AT&T Corp.
#
#                                organization3 bractext1  \
# 231       AT&T INTELLECTUAL PROPERTY I, L.P.
# 266      AT&T Intellectual Property II, L.P.
# 312                   AT&T Bell Laboratories
# 867                   AT&T Bell Laboratories
# 1377     AT&T Intellectual Property II, L.P.
